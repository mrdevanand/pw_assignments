# %% [markdown]
# que 1. Build a simple webpage that displays text as shown in the below image.

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Text Formatting Demo</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            padding: 20px;
        }
        mark {
            background-color: yellow;
        }
        .example {
            margin-bottom: 15px;
        }
    </style>
</head>
<body>

    <h2>Text Formatting Examples</h2>
    <div class="example"><i>This is italic</i></div>
    <div class="example"><u>This is underlined</u></div>
    <div class="example"><mark>This is highlighted</mark></div>
    <div class="example"><small>This is small text</small></div>
    <div class="example"><sup>This is superscript</sup></div>
    <div class="example"><sub>This is subscript</sub></div>
    <div class="example"><del>This is a deleted text</del></div>

</body>
</html>
# Out:
#   File "/tmp/ipython-input-7-1354198159.py", line 1
#     <h2>Text Formatting Examples</h2>
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# que 2  .Build a simple webpage that helps users navigate different web development-related websites. Note: On
# clicking the hyperlink the web pages should open in a new tab. Below is a reference image

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Web Dev Navigation</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            background: #f2f2f2;
            padding: 30px;
        }

        h2 {
            text-align: center;
            color: #333;
        }

        .link-box {
            background-color: #fff;
            padding: 15px 25px;
            margin: 15px auto;
            max-width: 500px;
            border-radius: 8px;
            box-shadow: 0 2px 6px rgba(0,0,0,0.1);
            transition: transform 0.2s;
        }

        .link-box:hover {
            transform: scale(1.02);
            background-color: #eaf6ff;
        }

        a {
            text-decoration: none;
            color: #007BFF;
            font-size: 18px;
            font-weight: bold;
        }

        p {
            margin: 5px 0 0;
            color: #555;
        }
    </style>
</head>
<body>

    <h2>🌐 my Web Resources</h2>

    <div class="link-box">
        <a href="https://www.pwskills.com/" target="_blank">Go to PW Skills</a>
        <p>Take me to PW Skills to buy a course.</p>
    </div>

    <div class="link-box">
        <a href="https://developer.mozilla.org/" target="_blank">Visit MDN Web Docs</a>
        <p>Take me to MDN Docs to know more about development.</p>
    </div>

    <div class="link-box">
        <a href="https://www.pwlabs.in/" target="_blank">Go to PW Labs</a>
        <p>Take me to PW Labs for live coding practice.</p>
    </div>

</body>
</html>

# %% [markdown]
# que 3. Build a simple blog web page with 3 pages home, web development, and web design. Each page must
# contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information.
# For the home page you can add some information about yourself

# %%
<!DOCTYPE html>
<html>
<head>
    <title>My Blog </title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 0;
            padding: 0;
            scroll-behavior: smooth;
        }

        header {
            background-color: #007BFF;
            padding: 15px 20px;
            color: white;
            position: sticky;
            top: 0;
            z-index: 1000;
        }

        nav a {
            margin-right: 20px;
            text-decoration: none;
            color: white;
            font-weight: bold;
        }

        section {
            padding: 40px 20px;
            border-bottom: 1px solid #ccc;
        }

        h2 {
            color: #007BFF;
        }

        footer {
            text-align: center;
            padding: 20px;
            background: #f1f1f1;
        }
    </style>
</head>
<body>

    <header>
        <nav>
            <a href="#home">Home</a>
            <a href="#webdev">Web Development</a>
            <a href="#webdesign">Web Design</a>
        </nav>
    </header>

    <section id="home">
        <h2>🏠 Home</h2>
        <p>Hello! I'm Devanand, a passionate web developer and designer. I love building interactive, user-friendly websites and exploring new technologies. This blog shares my journey, learning, and tips about web development and design.</p>
    </section>

    <section id="webdev">
        <h2>💻 Web Development</h2>
        <p>Web development involves building websites and applications using languages like HTML, CSS, JavaScript, and frameworks like React or Angular. Developers handle both front-end (what users see) and back-end (server-side logic) to create dynamic experiences.</p>
    </section>

    <section id="webdesign">
        <h2>🎨 Web Design</h2>
        <p>Web design focuses on the visual layout and user experience of a website. It involves choosing colors, typography, spacing, and creating responsive layouts. A good design enhances usability and leaves a positive impression on users.</p>
    </section>

    <footer>
        &copy; 2025 My Blog by Devanand
    </footer>

</body>
</html>

# %% [markdown]
# que 4.  Create an ordered list of HTML tags. Each list item must include the tag name and some information about
# the tag

# %%
<!DOCTYPE html>
<html>
<head>
    <title>HTML Tags List</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            padding: 30px;
            background-color: #f9f9f9;
        }

        h1 {
            color: #333;
        }

        ol {
            background-color: #fff;
            padding: 20px;
            border-radius: 8px;
            box-shadow: 0 0 5px rgba(0,0,0,0.1);
        }

        li {
            margin-bottom: 15px;
            line-height: 1.5;
        }

        code {
            background-color: #eef;
            padding: 2px 5px;
            border-radius: 4px;
            font-family: monospace;
        }
    </style>
</head>
<body>

    <h1>📄 Ordered List of HTML Tags</h1>

    <ol>
        <li><code>&lt;html&gt;</code> – The root element of an HTML document.</li>
        <li><code>&lt;head&gt;</code> – Contains metadata about the document, like title and links to styles.</li>
        <li><code>&lt;title&gt;</code> – Sets the title of the document shown in the browser tab.</li>
        <li><code>&lt;body&gt;</code> – Contains all the visible content of the web page.</li>
        <li><code>&lt;h1&gt; to &lt;h6&gt;</code> – Header tags for defining headings (h1 is largest, h6 is smallest).</li>
        <li><code>&lt;p&gt;</code> – Paragraph tag used to write blocks of text.</li>
        <li><code>&lt;a&gt;</code> – Anchor tag used to create hyperlinks.</li>
        <li><code>&lt;img&gt;</code> – Embeds images into the page using the `src` attribute.</li>
        <li><code>&lt;ul&gt;</code> – Creates an unordered (bulleted) list.</li>
        <li><code>&lt;ol&gt;</code> – Creates an ordered (numbered) list.</li>
        <li><code>&lt;li&gt;</code> – List item tag used inside <code>&lt;ul&gt;</code> or <code>&lt;ol&gt;</code>.</li>
        <li><code>&lt;div&gt;</code> – Generic container for grouping content.</li>
        <li><code>&lt;span&gt;</code> – Inline container for styling small pieces of text.</li>
        <li><code>&lt;br&gt;</code> – Inserts a line break.</li>
        <li><code>&lt;input&gt;</code> – Creates form input fields like textboxes, checkboxes, etc.</li>
        <li><code>&lt;form&gt;</code> – Container for form elements to collect user input.</li>
        <li><code>&lt;button&gt;</code> – Represents a clickable button.</li>
        <li><code>&lt;table&gt;</code> – Defines a table.</li>
        <li><code>&lt;tr&gt;</code> – Table row inside a table.</li>
        <li><code>&lt;td&gt;</code> – Table data cell inside a row.</li>
    </ol>

</body>
</html>

# %% [markdown]
# que 5.  Create a description list of full stack web development tech stack, using the <dl> tag. Each term should be
# a tech stack name and each description should be a brief explanation of what the tech stack is used for

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Full Stack Web Development Tech Stack</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            padding: 30px;
            background-color: #f9f9f9;
        }

        h1 {
            color: #333;
        }

        dl {
            background-color: #fff;
            padding: 20px;
            border-radius: 8px;
            max-width: 700px;
            box-shadow: 0 0 6px rgba(0, 0, 0, 0.1);
        }

        dt {
            font-weight: bold;
            margin-top: 15px;
            color: #007BFF;
        }

        dd {
            margin-left: 20px;
            margin-bottom: 10px;
            color: #444;
        }
    </style>
</head>
<body>

    <h1>🧱 Full Stack Web Development Tech Stack</h1>

    <dl>
        <dt>HTML</dt>
        <dd>Defines the structure of web pages using elements like headings, paragraphs, links, and lists.</dd>

        <dt>CSS</dt>
        <dd>Used to style and layout web pages, including colors, fonts, and responsive design.</dd>

        <dt>JavaScript</dt>
        <dd>Makes web pages interactive with dynamic content and user-driven behavior.</dd>

        <dt>React</dt>
        <dd>A JavaScript library for building fast and interactive user interfaces, especially single-page applications (SPA).</dd>

        <dt>Node.js</dt>
        <dd>Allows JavaScript to run on the server-side, enabling full-stack JavaScript development.</dd>

        <dt>Express.js</dt>
        <dd>A lightweight Node.js framework for building server-side applications and APIs.</dd>

        <dt>MongoDB</dt>
        <dd>A NoSQL database that stores data in flexible JSON-like documents, ideal for modern web apps.</dd>

        <dt>Git & GitHub</dt>
        <dd>Used for version control and collaboration on code, allowing developers to track and manage changes.</dd>

        <dt>RESTful APIs</dt>
        <dd>Interfaces that allow frontend and backend to communicate over HTTP using standard methods like GET, POST, PUT, DELETE.</dd>

        <dt>Webpack</dt>
        <dd>A module bundler that prepares and optimizes frontend assets (HTML, CSS, JS) for deployment.</dd>

        <dt>VS Code</dt>
        <dd>A powerful code editor commonly used by developers for writing and debugging code.</dd>
    </dl>

</body>
</html>

# %% [markdown]
# que 6. Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech
# stack, create a table that lists the tech stack name, its primary use cases, and some key features or
# benefits. Below is a reference image.

# %%
<!DOCTYPE html>
<html>
<head>
    <title>Full Stack Web Development Tech Stack</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            padding: 30px;
            background-color: #f9f9f9;
        }

        h1 {
            text-align: center;
            color: #333;
        }

        ol {
            margin-top: 30px;
        }

        li {
            margin-bottom: 30px;
        }

        table {
            width: 100%;
            border-collapse: collapse;
            margin-top: 10px;
            background-color: #fff;
            box-shadow: 0 0 5px rgba(0,0,0,0.1);
        }

        th, td {
            border: 1px solid #ccc;
            padding: 10px 15px;
            text-align: left;
        }

        th {
            background-color: #007BFF;
            color: white;
        }

        td {
            background-color: #fefefe;
        }
    </style>
</head>
<body>

    <h1>💻 Full Stack Web Development Tech Stack</h1>

    <ol>
        <li>
            <strong>HTML (HyperText Markup Language)</strong>
            <table>
                <tr>
                    <th>Primary Use Cases</th>
                    <th>Key Features/Benefits</th>
                </tr>
                <tr>
                    <td>Building structure of webpage</td>
                    <td>
                        - Simple and easy to learn<br>
                        - Compitable with all web browsers<br>
                        - Allows semantic markup
                    </td>
                </tr>
            </table>
        </li>

        <li>
            <strong>CSS (Cascading Style Sheets)</strong>
            <table>
                <tr>
                    <th>Primary Use Cases</th>
                    <th>Key Features/Benefits</th>
                </tr>
                <tr>
                    <td>Styling and layout of webpage</td>
                    <td>
                        - Allows for sepration of content and presentation<br>
                        - Enables responsive design <br>
                        - Offers wide range of styling options
                    </td>
                </tr>
            </table>
        </li>


    </ol>

</body>
</html>

# %% [markdown]
# que 7.  Build a complex nested list structure representing a multi-level table of contents. Use unordered lists
# (<ul>) and list items (<li>) with inline-block styling to create a structured layout. Apply formatting tags to
# enhance the presentation of list items

# %%
<!DOCTYPE html>
<html>
<head>
  <title>Project Management TOC</title>
  <style>
    ul {
      list-style-type: disc;
    }
    li {
      display: block;
      margin: 5px 0;
    }
    h1 {
      color: #2a4d69;
    }
    h2 {
      color: #4b86b4;
    }
    strong {
      color: #000;
    }
    em {
      color: #555;
    }
  </style>
</head>
<body>

  <h1>📚 Table of Contents: Project Management</h1>

  <ul>
    <li><strong>Project: TaskMaster Pro</strong>
      <ul>
        <li><em>Description:</em> A smart task tracking system for teams.</li>
        <li><strong>Plugins:</strong>
          <ul>
            <li>TimeTracker - <em>Logs team hours with visual charts.</em></li>
            <li>NotificationPlus - <em>Real-time push/email alerts for deadlines.</em></li>
          </ul>
        </li>
        <li><strong>Libraries:</strong>
          <ul>
            <li>React.js - <em>Component-based UI development.</em></li>
            <li>Redux - <em>State management for complex workflows.</em></li>
          </ul>
        </li>
        <li><strong>Addons:</strong>
          <ul>
            <li>Dark Mode - <em>Enhances UI accessibility.</em></li>
            <li>Kanban View - <em>Drag-and-drop task boards.</em></li>
          </ul>
        </li>
      </ul>
    </li>

    <li><strong>Project: SprintTracker</strong>
      <ul>
        <li><em>Description:</em> Agile sprint and milestone tracker for software teams.</li>
        <li><strong>Plugins:</strong>
          <ul>
            <li>BurndownChart - <em>Tracks sprint progress visually.</em></li>
            <li>RetroBoard - <em>Facilitates team retrospectives.</em></li>
          </ul>
        </li>
        <li><strong>Libraries:</strong>
          <ul>
            <li>Vue.js - <em>Lightweight and reactive front-end framework.</em></li>
            <li>Axios - <em>API integration for backend services.</em></li>
          </ul>
        </li>
        <li><strong>Addons:</strong>
          <ul>
            <li>TeamChat - <em>Real-time in-app messaging.</em></li>
            <li>Calendar Sync - <em>Syncs with Google Calendar and Outlook.</em></li>
          </ul>
        </li>
      </ul>
    </li>

    <li><strong>Project: CollabSpace</strong>
      <ul>
        <li><em>Description:</em> A centralized workspace for collaboration and file sharing.</li>
        <li><strong>Plugins:</strong>
          <ul>
            <li>DriveConnect - <em>Integration with Google Drive and Dropbox.</em></li>
            <li>CommentHub - <em>Threaded comments on any document.</em></li>
          </ul>
        </li>
        <li><strong>Libraries:</strong>
          <ul>
            <li>Angular - <em>Powerful front-end framework for enterprise apps.</em></li>
            <li>Bootstrap - <em>Responsive layout and components.</em></li>
          </ul>
        </li>
        <li><strong>Addons:</strong>
          <ul>
            <li>Version Control - <em>Tracks all document edits and versions.</em></li>
            <li>Role Manager - <em>Advanced access control settings.</em></li>
          </ul>
        </li>
      </ul>
    </li>
  </ul>

</body>
</html>
